# %% [markdown]
# # My Jupyter Notebook on IBM WATSON

# %% [markdown]
# **Adrian Gomez Rodriguez**.
# I am an actuarial student

# %% [markdown]
# *Data science interests me as it is a branch of my career that I love how to interpret that data with mathematical models and be able to understand it in such an efficient way.*

# %% [markdown]
# ### The following line of code does the calculation of the sum of 1+1 and gives its result

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Table example
# | Numero | Nombre |
# | :---: | :---:|
# | 00 | XD |
#
# <hr>
#
# Blocked quotes example
# > Esto es un ejemplo en español
#
# <hr>
#
# List example
# 1. Numero 1
# 2. Numero 2
#     1. Letra A
#         1. Letra a
#
# <hr>
#
# Imagine example
#
# ![download.jpg](attachment:0511a7dc-32ad-488e-b0d3-2d65b63afe57.jpg)
